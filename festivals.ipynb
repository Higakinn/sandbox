# %% [markdown]
# <a href="https://colab.research.google.com/github/Higakinn/sandbox/blob/main/festivals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas==1.5.2
# !pip install beautifulsoup4==4.9.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 115 kB 7.2 MB/s
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.2'

# %%
import pandas as pd


url="https://www.city.niihama.lg.jp/soshiki/kankou/taikodaiichiran.html"

dfs = pd.read_html(url,extract_links="all")

# %%
dfs[0]
# dfs[0].info()
# Out:
#                                                 0  \
# 0                                   (大生院地区, None)
# 1   (上本郷（かみほんごう）, /uploaded/attachment/12965.jpg)
# 2      (岸影（きしかげ）, /uploaded/attachment/38826.JPG)
# 3       (喜来（きらい）, /uploaded/attachment/38827.JPG)
# 4   (下本郷（しもほんごう）, /uploaded/attachment/12962.jpg)
# 5                                        (, None)
# 6                                        (, None)
# 7                                        (, None)
# 8                                        (, None)
# 9                                        (, None)
# 10                                       (, None)
# 11                                       (, None)
# 12                                       (, None)
# 13                                       (, None)
#
#                                               1  \
# 0                                  (川東地区, None)
# 1     (阿島（あしま）, /uploaded/attachment/38828.JPG)
# 2    (楠崎（くっさき）, /uploaded/attachment/12946.jpg)
# ...

# %%
import pandas as pd
url = 'http://www.saijomatsuri.jp/yatai/'
saijyo_dfs= pd.read_html(url,extract_links="all")

# %%
isono_df = saijyo_dfs[0]
iwaoka_df = saijyo_dfs[1]
iizumi_df = saijyo_dfs[2]
isono_df
saijyo_dfs
# Out:
# [                                             0  \
#  0     (中野, http://www.saijomatsuri.jp/?p=1941)
#  1    (洲之内, http://www.saijomatsuri.jp/?p=1978)
#  2    (川原町, http://www.saijomatsuri.jp/?p=1998)
#  3  (駅前本通り, http://www.saijomatsuri.jp/?p=2017)
#  4    (若葉町, http://www.saijomatsuri.jp/?p=2035)
#  5   (栄町上組, http://www.saijomatsuri.jp/?p=2053)
#  6    (若草町, http://www.saijomatsuri.jp/?p=2071)
#  7     (横黒, http://www.saijomatsuri.jp/?p=2089)
#  8    (紺屋町, http://www.saijomatsuri.jp/?p=2107)
#
#                                              1  \
#  0    (山道, http://www.saijomatsuri.jp/?p=1942)
#  1   (奥之内, http://www.saijomatsuri.jp/?p=1981)
#  2    (西町, http://www.saijomatsuri.jp/?p=2000)
#  3   (上小川, http://www.saijomatsuri.jp/?p=2019)
#  4    (錦町, http://www.saijomatsuri.jp/?p=2037)
#  5  (栄町中組, http://www.saijomatsuri.jp/?p=2055)
#  6   (花園町, http://www.saijomatsuri.jp/?p=2073)
#  7    (市塚, http://www.saijomatsuri.jp/?p=2091)
#  8    (東町, http://www.saijomatsuri.jp/?p=2109)
#
# ...
